# %%
"""CIS 2532 NET 01
Dr. Shamsuddin
Kostas Spyropoulos
HW 7 
Program performs various uses of NLP
Exercise 12.3"""
import requests
import nltk
from nltk.corpus import stopwords
import imageio
from wordcloud import WordCloud
from textblob import TextBlob
import matplotlib.pyplot as plt
from textblob.sentiments import NaiveBayesAnalyzer
from bs4 import BeautifulSoup
from unidecode import unidecode
from textblob import Word
from spellchecker import SpellChecker

# Exercise 12.3

print('Exercise 12.3')
print()

# the get function gets the URL argument and sends the URL's webpage as a Response object
response = requests.get('https://www.cnn.com/2022/03/25/entertainment/taylor-hawkins-foo-fighters-obit/index.html')

# reponse.content possesses web page's composition
response.content 

# BeautifulSoup object is made to analyze text of response.content
soup = BeautifulSoup(response.content,'html5lib')

# text of website is returned without web browser structural info
text = soup.get_text(strip=True)

# blob is equal to textblob of 'https://www.cnn.com/2022/03/25/entertainment/taylor-hawkins-foo-fighters-obit/index.html'
blob = TextBlob(text)

print()
print('Overall sentiment of https://www.cnn.com/2022/03/25/entertainment/taylor-hawkins-foo-fighters-obit/index.html')

# print the sentiment of overall blob
print(blob.sentiment)
print()

print('Sentiment of each sentence of https://www.cnn.com/2022/03/25/entertainment/taylor-hawkins-foo-fighters-obit/index.html')

counter = 0
# print the sentiment of every sentence in blob
for sentence in blob.sentences:
    counter = counter + 1
    # counter represents cardinal number of sentence sentiment
    print(str(counter) + str(". ")+ str(sentence.sentiment))
# Out:
# Exercise 12.3
#
#
# Overall sentiment of https://www.cnn.com/2022/03/25/entertainment/taylor-hawkins-foo-fighters-obit/index.html
# Sentiment(polarity=-0.3805922433264658, subjectivity=0.7822017843536253)
#
# Sentiment of each sentence of https://www.cnn.com/2022/03/25/entertainment/taylor-hawkins-foo-fighters-obit/index.html
# 1. Sentiment(polarity=-0.375, subjectivity=0.55)
# 2. Sentiment(polarity=-0.17158723153868777, subjectivity=0.45769659143445574)
# 3. Sentiment(polarity=-0.75, subjectivity=1.0)
# 4. Sentiment(polarity=0.5, subjectivity=0.5)
# 5. Sentiment(polarity=0.0, subjectivity=0.0)
# 6. Sentiment(polarity=0.0, subjectivity=0.0)
# 7. Sentiment(polarity=-0.28534080298786196, subjectivity=0.7247432306255835)
# 8. Sentiment(polarity=0.0, subjectivity=0.0)
# 9. Sentiment(polarity=0.0, subjectivity=0.0)
# 10. Sentiment(polarity=-0.25, subjectivity=0.6)
# 11. Sentiment(polarity=-0.125, subjectivity=0.75)
# 12. Sentiment(polarity=0.0, subjectivity=0.0)
# 13. Sentiment(polarity=0.0, subjectivity=0.0)
# 14. Sentiment(polarity=0.0, subjectivity=0.3333333333333333)
# 15. Sentiment(polarity=0.0, subjectivity=0.3)
# 16. Sentiment(polarity=0.0, subjectivity=0.0)
# 17. Sentiment(polarity=-0.4, subjectivity=0.7)
# 18. Sentiment(polarity=0.0, subjectivity=0.0)
# 19. Sentiment(polarity=0.5, subjectivity=0.15)
# 20. Sentiment(polarity=0.0, subjectivity=0.5)
# 21. Sentiment(polarity=0.21428571428571427, subjectivity=0.6428571428571429)
# 22. Sentiment(polarity=0.175, subjectivity=0.49000000000000005)
# 23. Sentiment(polarity=0.0, subjectivity=0.0)
# 24. Sentiment(polarity=0.0, subjectivity=0.0)
# 25. Sentiment(polarity=0.0, subjectivity=0.0)
# 26. Sentiment(polarity=0.0, subjectivity=0.0)
# 27. Sentiment(polarity=0.7, subjectivity=0.9)
# 28. Sentiment(polarity=0.06666666666666667, subjectivity=0.39999999999999997)
# 29. Sentiment(polarity=0.0, subjectivity=0.0)
# 30. Sentiment(polarity=0.0, subjectivity=0.0)
# 31. Sentiment(polarity=0.0, subjectivity=0.0)
# 32. Sentiment(polarity=0.5, subjectivity=0.5)
# 33. Sentiment(polarity=0.0, subjectivity=0.0)
# 34. Sentiment(polarity=0.35, subjectivity=0.65)
# 35. Sentiment(polarity=1.0, subjectivity=0.3)
# 36. Sentiment(polarity=0.0, subjectivity=0.0)
# 37. Sentiment(polarity=0.35, subjectivity=0.65)
# 38. Sentiment(polarity=0.3333333333333333, subjectivity=0.6666666666666666)
# 39. Sentiment(polarity=0.35, subjectivity=0.65)
# 40. Sentiment(polarity=0.25909090909090904, subjectivity=0.4636363636363636)
# 41. Sentiment(polarity=0.43333333333333335, subjectivity=0.8333333333333334)
# 42. Sentiment(polarity=0.4, subjectivity=0.425)
# 43. Sentiment(polarity=0.0, subjectivity=0.0)
# 44. Sentiment(polarity=0.8, subjectivity=0.75)
# 45. Sentiment(polarity=-0.2380952380952381, subjectivity=0.48571428571428577)
# 46. Sentiment(polarity=0.0, subjectivity=0.0)
# 47. Sentiment(polarity=0.0, subjectivity=0.0)
# 48. Sentiment(polarity=0.0, subjectivity=0.0)
# 49. Sentiment(polarity=0.0, subjectivity=0.0)
# 50. Sentiment(polarity=0.35, subjectivity=0.65)
# 51. Sentiment(polarity=0.4330357142857143, subjectivity=0.7053571428571428)
# 52. Sentiment(polarity=0.0, subjectivity=0.0)
# 53. Sentiment(polarity=0.0, subjectivity=0.0)
# 54. Sentiment(polarity=0.0, subjectivity=0.0)
# 55. Sentiment(polarity=0.0, subjectivity=0.0)
# 56. Sentiment(polarity=1.0, subjectivity=0.3)
# 57. Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# 58. Sentiment(polarity=0.0, subjectivity=0.0)
# 59. Sentiment(polarity=0.0, subjectivity=0.0)
# 60. Sentiment(polarity=0.43333333333333335, subjectivity=0.6)
# 61. Sentiment(polarity=0.0, subjectivity=0.0)
# 62. Sentiment(polarity=0.0, subjectivity=0.0)
# 63. Sentiment(polarity=0.0, subjectivity=0.0)
# 64. Sentiment(polarity=0.0, subjectivity=0.0)
# 65. Sentiment(polarity=0.0, subjectivity=0.0)
# 66. Sentiment(polarity=0.0, subjectivity=0.0)
# 67. Sentiment(polarity=0.0, subjectivity=0.0)
# 68. Sentiment(polarity=0.0, subjectivity=0.0)
# 69. Sentiment(polarity=0.0, subjectivity=0.0)
# 70. Sentiment(polarity=-0.37940539852304556, subjectivity=0.867436974789916)
# 71. Sentiment(polarity=-0.6031088082901558, subjectivity=0.9138601036269428)
# 72. Sentiment(polarity=0.0, subjectivity=0.0)
# 73. Sentiment(polarity=-0.491304347826087, subjectivity=0.7956521739130435)
# 74. Sentiment(polarity=0.040000000000000015, subjectivity=0.72)
# 75. Sentiment(polarity=0.0, subjectivity=0.0)
# 76. Sentiment(polarity=0.0, subjectivity=1.0)
# 77. Sentiment(polarity=-0.5, subjectivity=0.6666666666666666)
# 78. Sentiment(polarity=0.0, subjectivity=0.0)
# 79. Sentiment(polarity=-0.25, subjectivity=0.3333333333333333)
# 80. Sentiment(polarity=0.0, subjectivity=0.0)
# 81. Sentiment(polarity=-0.2681818181818182, subjectivity=0.656060606060606)
# 82. Sentiment(polarity=-0.053125000000000006, subjectivity=0.4125)
# 83. Sentiment(polarity=-0.03697916666666667, subjectivity=0.20416666666666666)
# 84. Sentiment(polarity=-0.008333333333333331, subjectivity=0.125)
# 85. Sentiment(polarity=0.0, subjectivity=0.1)
# 86. Sentiment(polarity=-0.75, subjectivity=1.0)
# 87. Sentiment(polarity=0.0, subjectivity=0.0)
# 88. Sentiment(polarity=-0.125, subjectivity=0.75)
# 89. Sentiment(polarity=-0.32142857142857145, subjectivity=0.42857142857142855)
# 90. Sentiment(polarity=0.040000000000000015, subjectivity=0.72)
# 91. Sentiment(polarity=0.0, subjectivity=0.0)
# 92. Sentiment(polarity=0.0, subjectivity=1.0)
# 93. Sentiment(polarity=-0.5, subjectivity=0.6666666666666666)
# 94. Sentiment(polarity=0.0, subjectivity=0.0)
# 95. Sentiment(polarity=-0.25, subjectivity=0.3333333333333333)
# 96. Sentiment(polarity=0.0, subjectivity=0.0)
# 97. Sentiment(polarity=-0.2681818181818182, subjectivity=0.656060606060606)
# 98. Sentiment(polarity=-0.053125000000000006, subjectivity=0.4125)
# 99. Sentiment(polarity=-0.03697916666666667, subjectivity=0.20416666666666666)
# 100. Sentiment(polarity=-0.008333333333333331, subjectivity=0.125)
# 101. Sentiment(polarity=0.0, subjectivity=0.1)
# 102. Sentiment(polarity=-0.75, subjectivity=1.0)
# 103. Sentiment(polarity=0.0, subjectivity=0.0)
# 104. Sentiment(polarity=-0.125, subjectivity=0.75)
# 105. Sentiment(polarity=-0.1392857142857143, subjectivity=0.688095238095238)
# 106. Sentiment(polarity=0.0, subjectivity=0.0)
# 107. Sentiment(polarity=0.25, subjectivity=0.45)
# 108. Sentiment(polarity=-0.11428571428571428, subjectivity=0.6630952380952381)
# 109. Sentiment(polarity=0.20000000000000004, subjectivity=0.43333333333333335)
# 110. Sentiment(polarity=-0.23714285714285716, subjectivity=0.6957142857142856)
# 111. Sentiment(polarity=-0.19090909090909092, subjectivity=0.8590909090909092)
# 112. Sentiment(polarity=-0.75, subjectivity=1.0)
# 113. Sentiment(polarity=0.5, subjectivity=0.5)
# 114. Sentiment(polarity=0.0, subjectivity=0.0)
# 115. Sentiment(polarity=0.0, subjectivity=0.0)
# 116. Sentiment(polarity=-0.5203125, subjectivity=0.903125)
# 117. Sentiment(polarity=0.0, subjectivity=0.0)
# 118. Sentiment(polarity=-0.375, subjectivity=0.7)
# 119. Sentiment(polarity=-0.75, subjectivity=1.0)
# 120. Sentiment(polarity=-0.75, subjectivity=1.0)
# 121. Sentiment(polarity=-0.48131313131313136, subjectivity=0.8222222222222224)
# 122. Sentiment(polarity=0.0, subjectivity=0.0)
# 123. Sentiment(polarity=-0.34999999999999987, subjectivity=0.8121212121212118)
# 124. Sentiment(polarity=-0.3468442501105831, subjectivity=0.8595397623035782)
# 125. Sentiment(polarity=0.0, subjectivity=0.0)
# 126. Sentiment(polarity=-0.375, subjectivity=0.7)
# 127. Sentiment(polarity=-0.75, subjectivity=1.0)
# 128. Sentiment(polarity=-0.75, subjectivity=1.0)
# 129. Sentiment(polarity=-0.48131313131313136, subjectivity=0.8222222222222224)
# 130. Sentiment(polarity=0.0, subjectivity=0.0)
# 131. Sentiment(polarity=-0.33409090909090894, subjectivity=0.7878787878787876)
# 132. Sentiment(polarity=0.0, subjectivity=0.0)
# 133. Sentiment(polarity=0.0, subjectivity=0.0)
# 134. Sentiment(polarity=0.0, subjectivity=0.0)
# 135. Sentiment(polarity=0.0, subjectivity=0.0)
# 136. Sentiment(polarity=-0.2520833333333334, subjectivity=0.425)
# 137. Sentiment(polarity=-0.44270007118161553, subjectivity=0.8017897091722591)
# 138. Sentiment(polarity=0.040000000000000015, subjectivity=0.72)
# 139. Sentiment(polarity=0.0, subjectivity=0.0)
# 140. Sentiment(polarity=0.0, subjectivity=1.0)
# 141. Sentiment(polarity=-0.5, subjectivity=0.6666666666666666)
# 142. Sentiment(polarity=0.0, subjectivity=0.0)
# 143. Sentiment(polarity=-0.25, subjectivity=0.3333333333333333)
# 144. Sentiment(polarity=0.0, subjectivity=0.0)
# 145. Sentiment(polarity=-0.2681818181818182, subjectivity=0.656060606060606)
# 146. Sentiment(polarity=-0.053125000000000006, subjectivity=0.4125)
# 147. Sentiment(polarity=-0.03697916666666667, subjectivity=0.20416666666666666)
# 148. Sentiment(polarity=-0.008333333333333331, subjectivity=0.125)
# 149. Sentiment(polarity=0.0, subjectivity=0.1)
# 150. Sentiment(polarity=-0.75, subjectivity=1.0)
# 151. Sentiment(polarity=0.0, subjectivity=0.0)
# 152. Sentiment(polarity=-0.125, subjectivity=0.75)
# 153. Sentiment(polarity=-0.453125, subjectivity=0.5916666666666667)
# 154. Sentiment(polarity=-0.20000000000000004, subjectivity=0.5625)
# 155. Sentiment(polarity=-0.46813186813186813, subjectivity=0.782967032967033)
# 156. Sentiment(polarity=0.35, subjectivity=0.65)
# 157. Sentiment(polarity=0.009987148268398268, subjectivity=0.5296536796536797)
# 158. Sentiment(polarity=-0.2, subjectivity=0.825)
# 159. Sentiment(polarity=0.11666666666666665, subjectivity=0.8833333333333333)
# 160. Sentiment(polarity=0.0, subjectivity=1.0)
# 161. Sentiment(polarity=0.16666666666666666, subjectivity=0.6)
# 162. Sentiment(polarity=0.0, subjectivity=0.0)
# 163. Sentiment(polarity=-0.025000000000000022, subjectivity=0.875)
# 164. Sentiment(polarity=0.06818181818181818, subjectivity=0.25)
# 165. Sentiment(polarity=-0.5, subjectivity=1.0)
# 166. Sentiment(polarity=0.5, subjectivity=0.5)
# 167. Sentiment(polarity=0.0, subjectivity=0.0)
# 168. Sentiment(polarity=0.0, subjectivity=0.0)
# 169. Sentiment(polarity=-0.5, subjectivity=1.0)
# 170. Sentiment(polarity=0.0, subjectivity=0.0)
# 171. Sentiment(polarity=0.08333333333333333, subjectivity=0.16666666666666666)
# 172. Sentiment(polarity=-0.05555555555555555, subjectivity=0.05555555555555555)
# 173. Sentiment(polarity=0.0, subjectivity=0.0)
# 174. Sentiment(polarity=0.0, subjectivity=0.0)
# 175. Sentiment(polarity=0.39285714285714285, subjectivity=0.5178571428571428)
# 176. Sentiment(polarity=0.0, subjectivity=0.0)
# 177. Sentiment(polarity=0.3, subjectivity=0.8666666666666667)
# 178. Sentiment(polarity=0.25, subjectivity=0.3)
# 179. Sentiment(polarity=-0.14583333333333334, subjectivity=0.3333333333333333)
# 180. Sentiment(polarity=0.1875, subjectivity=0.23333333333333334)
# 181. Sentiment(polarity=0.0, subjectivity=0.0)
# 182. Sentiment(polarity=0.1, subjectivity=0.2)
# 183. Sentiment(polarity=0.3125, subjectivity=0.3333333333333333)
# 184. Sentiment(polarity=0.0, subjectivity=0.0)
# 185. Sentiment(polarity=0.4375, subjectivity=0.55)
# 186. Sentiment(polarity=0.0, subjectivity=0.0)
# 187. Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# 188. Sentiment(polarity=0.125, subjectivity=0.6666666666666666)
# 189. Sentiment(polarity=0.13333333333333333, subjectivity=0.19999999999999998)
# 190. Sentiment(polarity=0.0, subjectivity=0.0)
# 191. Sentiment(polarity=0.7, subjectivity=0.8)
# 192. Sentiment(polarity=0.0, subjectivity=0.0)
# 193. Sentiment(polarity=0.0, subjectivity=0.0)
# 194. Sentiment(polarity=0.5, subjectivity=0.6)
# 195. Sentiment(polarity=0.7000000000000001, subjectivity=0.825)
# 196. Sentiment(polarity=0.5, subjectivity=0.6)
# 197. Sentiment(polarity=0.04464285714285714, subjectivity=0.5089285714285714)
# 198. Sentiment(polarity=-0.45099718035275094, subjectivity=0.8211859527921701)
# 199. Sentiment(polarity=0.4375, subjectivity=0.65)
# 200. Sentiment(polarity=0.0, subjectivity=0.0)

# %%
"""CIS 2532 NET 01
Dr. Shamsuddin
Kostas Spyropoulos
HW 7 
Program performs various uses of NLP
Exercise 12.3"""
import requests
import nltk
from nltk.corpus import stopwords
import imageio
from wordcloud import WordCloud
from textblob import TextBlob
import matplotlib.pyplot as plt
from textblob.sentiments import NaiveBayesAnalyzer
from bs4 import BeautifulSoup
from unidecode import unidecode
from textblob import Word
from spellchecker import SpellChecker

# Exercise 12.3

print('Exercise 12.3')
print()

# the get function gets the URL argument and sends the URL's webpage as a Response object
response = requests.get('https://www.cnn.com/2022/03/25/entertainment/taylor-hawkins-foo-fighters-obit/index.html')

# reponse.content possesses web page's composition
response.content 

# BeautifulSoup object is made to analyze text of response.content
soup = BeautifulSoup(response.content,'html5lib')

# text of website is returned without web browser structural info
text = soup.get_text(strip=True)

# blob is equal to textblob of 'https://www.cnn.com/2022/03/25/entertainment/taylor-hawkins-foo-fighters-obit/index.html'
blob = TextBlob(text)

print()
print('Overall sentiment of https://www.cnn.com/2022/03/25/entertainment/taylor-hawkins-foo-fighters-obit/index.html')

# print the sentiment of overall blob
print(blob.sentiment)
print()

print('Sentiment of each sentence of https://www.cnn.com/2022/03/25/entertainment/taylor-hawkins-foo-fighters-obit/index.html')

counter = 0
# print the sentiment of every sentence in blob
for sentence in blob.sentences:
    counter = counter + 1
    # counter represents cardinal number of sentence sentiment
    print(str(counter) + str(". ")+ str(sentence.sentiment))
# Out:
# Exercise 12.3
#
#
# Overall sentiment of https://www.cnn.com/2022/03/25/entertainment/taylor-hawkins-foo-fighters-obit/index.html
# Sentiment(polarity=-0.3805922433264658, subjectivity=0.7822017843536253)
#
# Sentiment of each sentence of https://www.cnn.com/2022/03/25/entertainment/taylor-hawkins-foo-fighters-obit/index.html
# 1. Sentiment(polarity=-0.375, subjectivity=0.55)
# 2. Sentiment(polarity=-0.17158723153868777, subjectivity=0.45769659143445574)
# 3. Sentiment(polarity=-0.75, subjectivity=1.0)
# 4. Sentiment(polarity=0.5, subjectivity=0.5)
# 5. Sentiment(polarity=0.0, subjectivity=0.0)
# 6. Sentiment(polarity=0.0, subjectivity=0.0)
# 7. Sentiment(polarity=-0.28534080298786196, subjectivity=0.7247432306255835)
# 8. Sentiment(polarity=0.0, subjectivity=0.0)
# 9. Sentiment(polarity=0.0, subjectivity=0.0)
# 10. Sentiment(polarity=-0.25, subjectivity=0.6)
# 11. Sentiment(polarity=-0.125, subjectivity=0.75)
# 12. Sentiment(polarity=0.0, subjectivity=0.0)
# 13. Sentiment(polarity=0.0, subjectivity=0.0)
# 14. Sentiment(polarity=0.0, subjectivity=0.3333333333333333)
# 15. Sentiment(polarity=0.0, subjectivity=0.3)
# 16. Sentiment(polarity=0.0, subjectivity=0.0)
# 17. Sentiment(polarity=-0.4, subjectivity=0.7)
# 18. Sentiment(polarity=0.0, subjectivity=0.0)
# 19. Sentiment(polarity=0.5, subjectivity=0.15)
# 20. Sentiment(polarity=0.0, subjectivity=0.5)
# 21. Sentiment(polarity=0.21428571428571427, subjectivity=0.6428571428571429)
# 22. Sentiment(polarity=0.175, subjectivity=0.49000000000000005)
# 23. Sentiment(polarity=0.0, subjectivity=0.0)
# 24. Sentiment(polarity=0.0, subjectivity=0.0)
# 25. Sentiment(polarity=0.0, subjectivity=0.0)
# 26. Sentiment(polarity=0.0, subjectivity=0.0)
# 27. Sentiment(polarity=0.7, subjectivity=0.9)
# 28. Sentiment(polarity=0.06666666666666667, subjectivity=0.39999999999999997)
# 29. Sentiment(polarity=0.0, subjectivity=0.0)
# 30. Sentiment(polarity=0.0, subjectivity=0.0)
# 31. Sentiment(polarity=0.0, subjectivity=0.0)
# 32. Sentiment(polarity=0.5, subjectivity=0.5)
# 33. Sentiment(polarity=0.0, subjectivity=0.0)
# 34. Sentiment(polarity=0.35, subjectivity=0.65)
# 35. Sentiment(polarity=1.0, subjectivity=0.3)
# 36. Sentiment(polarity=0.0, subjectivity=0.0)
# 37. Sentiment(polarity=0.35, subjectivity=0.65)
# 38. Sentiment(polarity=0.3333333333333333, subjectivity=0.6666666666666666)
# 39. Sentiment(polarity=0.35, subjectivity=0.65)
# 40. Sentiment(polarity=0.25909090909090904, subjectivity=0.4636363636363636)
# 41. Sentiment(polarity=0.43333333333333335, subjectivity=0.8333333333333334)
# 42. Sentiment(polarity=0.4, subjectivity=0.425)
# 43. Sentiment(polarity=0.0, subjectivity=0.0)
# 44. Sentiment(polarity=0.8, subjectivity=0.75)
# 45. Sentiment(polarity=-0.2380952380952381, subjectivity=0.48571428571428577)
# 46. Sentiment(polarity=0.0, subjectivity=0.0)
# 47. Sentiment(polarity=0.0, subjectivity=0.0)
# 48. Sentiment(polarity=0.0, subjectivity=0.0)
# 49. Sentiment(polarity=0.0, subjectivity=0.0)
# 50. Sentiment(polarity=0.35, subjectivity=0.65)
# 51. Sentiment(polarity=0.4330357142857143, subjectivity=0.7053571428571428)
# 52. Sentiment(polarity=0.0, subjectivity=0.0)
# 53. Sentiment(polarity=0.0, subjectivity=0.0)
# 54. Sentiment(polarity=0.0, subjectivity=0.0)
# 55. Sentiment(polarity=0.0, subjectivity=0.0)
# 56. Sentiment(polarity=1.0, subjectivity=0.3)
# 57. Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# 58. Sentiment(polarity=0.0, subjectivity=0.0)
# 59. Sentiment(polarity=0.0, subjectivity=0.0)
# 60. Sentiment(polarity=0.43333333333333335, subjectivity=0.6)
# 61. Sentiment(polarity=0.0, subjectivity=0.0)
# 62. Sentiment(polarity=0.0, subjectivity=0.0)
# 63. Sentiment(polarity=0.0, subjectivity=0.0)
# 64. Sentiment(polarity=0.0, subjectivity=0.0)
# 65. Sentiment(polarity=0.0, subjectivity=0.0)
# 66. Sentiment(polarity=0.0, subjectivity=0.0)
# 67. Sentiment(polarity=0.0, subjectivity=0.0)
# 68. Sentiment(polarity=0.0, subjectivity=0.0)
# 69. Sentiment(polarity=0.0, subjectivity=0.0)
# 70. Sentiment(polarity=-0.37940539852304556, subjectivity=0.867436974789916)
# 71. Sentiment(polarity=-0.6031088082901558, subjectivity=0.9138601036269428)
# 72. Sentiment(polarity=0.0, subjectivity=0.0)
# 73. Sentiment(polarity=-0.491304347826087, subjectivity=0.7956521739130435)
# 74. Sentiment(polarity=0.040000000000000015, subjectivity=0.72)
# 75. Sentiment(polarity=0.0, subjectivity=0.0)
# 76. Sentiment(polarity=0.0, subjectivity=1.0)
# 77. Sentiment(polarity=-0.5, subjectivity=0.6666666666666666)
# 78. Sentiment(polarity=0.0, subjectivity=0.0)
# 79. Sentiment(polarity=-0.25, subjectivity=0.3333333333333333)
# 80. Sentiment(polarity=0.0, subjectivity=0.0)
# 81. Sentiment(polarity=-0.2681818181818182, subjectivity=0.656060606060606)
# 82. Sentiment(polarity=-0.053125000000000006, subjectivity=0.4125)
# 83. Sentiment(polarity=-0.03697916666666667, subjectivity=0.20416666666666666)
# 84. Sentiment(polarity=-0.008333333333333331, subjectivity=0.125)
# 85. Sentiment(polarity=0.0, subjectivity=0.1)
# 86. Sentiment(polarity=-0.75, subjectivity=1.0)
# 87. Sentiment(polarity=0.0, subjectivity=0.0)
# 88. Sentiment(polarity=-0.125, subjectivity=0.75)
# 89. Sentiment(polarity=-0.32142857142857145, subjectivity=0.42857142857142855)
# 90. Sentiment(polarity=0.040000000000000015, subjectivity=0.72)
# 91. Sentiment(polarity=0.0, subjectivity=0.0)
# 92. Sentiment(polarity=0.0, subjectivity=1.0)
# 93. Sentiment(polarity=-0.5, subjectivity=0.6666666666666666)
# 94. Sentiment(polarity=0.0, subjectivity=0.0)
# 95. Sentiment(polarity=-0.25, subjectivity=0.3333333333333333)
# 96. Sentiment(polarity=0.0, subjectivity=0.0)
# 97. Sentiment(polarity=-0.2681818181818182, subjectivity=0.656060606060606)
# 98. Sentiment(polarity=-0.053125000000000006, subjectivity=0.4125)
# 99. Sentiment(polarity=-0.03697916666666667, subjectivity=0.20416666666666666)
# 100. Sentiment(polarity=-0.008333333333333331, subjectivity=0.125)
# 101. Sentiment(polarity=0.0, subjectivity=0.1)
# 102. Sentiment(polarity=-0.75, subjectivity=1.0)
# 103. Sentiment(polarity=0.0, subjectivity=0.0)
# 104. Sentiment(polarity=-0.125, subjectivity=0.75)
# 105. Sentiment(polarity=-0.1392857142857143, subjectivity=0.688095238095238)
# 106. Sentiment(polarity=0.0, subjectivity=0.0)
# 107. Sentiment(polarity=0.25, subjectivity=0.45)
# 108. Sentiment(polarity=-0.11428571428571428, subjectivity=0.6630952380952381)
# 109. Sentiment(polarity=0.20000000000000004, subjectivity=0.43333333333333335)
# 110. Sentiment(polarity=-0.23714285714285716, subjectivity=0.6957142857142856)
# 111. Sentiment(polarity=-0.19090909090909092, subjectivity=0.8590909090909092)
# 112. Sentiment(polarity=-0.75, subjectivity=1.0)
# 113. Sentiment(polarity=0.5, subjectivity=0.5)
# 114. Sentiment(polarity=0.0, subjectivity=0.0)
# 115. Sentiment(polarity=0.0, subjectivity=0.0)
# 116. Sentiment(polarity=-0.5203125, subjectivity=0.903125)
# 117. Sentiment(polarity=0.0, subjectivity=0.0)
# 118. Sentiment(polarity=-0.375, subjectivity=0.7)
# 119. Sentiment(polarity=-0.75, subjectivity=1.0)
# 120. Sentiment(polarity=-0.75, subjectivity=1.0)
# 121. Sentiment(polarity=-0.48131313131313136, subjectivity=0.8222222222222224)
# 122. Sentiment(polarity=0.0, subjectivity=0.0)
# 123. Sentiment(polarity=-0.34999999999999987, subjectivity=0.8121212121212118)
# 124. Sentiment(polarity=-0.3468442501105831, subjectivity=0.8595397623035782)
# 125. Sentiment(polarity=0.0, subjectivity=0.0)
# 126. Sentiment(polarity=-0.375, subjectivity=0.7)
# 127. Sentiment(polarity=-0.75, subjectivity=1.0)
# 128. Sentiment(polarity=-0.75, subjectivity=1.0)
# 129. Sentiment(polarity=-0.48131313131313136, subjectivity=0.8222222222222224)
# 130. Sentiment(polarity=0.0, subjectivity=0.0)
# 131. Sentiment(polarity=-0.33409090909090894, subjectivity=0.7878787878787876)
# 132. Sentiment(polarity=0.0, subjectivity=0.0)
# 133. Sentiment(polarity=0.0, subjectivity=0.0)
# 134. Sentiment(polarity=0.0, subjectivity=0.0)
# 135. Sentiment(polarity=0.0, subjectivity=0.0)
# 136. Sentiment(polarity=-0.2520833333333334, subjectivity=0.425)
# 137. Sentiment(polarity=-0.44270007118161553, subjectivity=0.8017897091722591)
# 138. Sentiment(polarity=0.040000000000000015, subjectivity=0.72)
# 139. Sentiment(polarity=0.0, subjectivity=0.0)
# 140. Sentiment(polarity=0.0, subjectivity=1.0)
# 141. Sentiment(polarity=-0.5, subjectivity=0.6666666666666666)
# 142. Sentiment(polarity=0.0, subjectivity=0.0)
# 143. Sentiment(polarity=-0.25, subjectivity=0.3333333333333333)
# 144. Sentiment(polarity=0.0, subjectivity=0.0)
# 145. Sentiment(polarity=-0.2681818181818182, subjectivity=0.656060606060606)
# 146. Sentiment(polarity=-0.053125000000000006, subjectivity=0.4125)
# 147. Sentiment(polarity=-0.03697916666666667, subjectivity=0.20416666666666666)
# 148. Sentiment(polarity=-0.008333333333333331, subjectivity=0.125)
# 149. Sentiment(polarity=0.0, subjectivity=0.1)
# 150. Sentiment(polarity=-0.75, subjectivity=1.0)
# 151. Sentiment(polarity=0.0, subjectivity=0.0)
# 152. Sentiment(polarity=-0.125, subjectivity=0.75)
# 153. Sentiment(polarity=-0.453125, subjectivity=0.5916666666666667)
# 154. Sentiment(polarity=-0.20000000000000004, subjectivity=0.5625)
# 155. Sentiment(polarity=-0.46813186813186813, subjectivity=0.782967032967033)
# 156. Sentiment(polarity=0.35, subjectivity=0.65)
# 157. Sentiment(polarity=0.009987148268398268, subjectivity=0.5296536796536797)
# 158. Sentiment(polarity=-0.2, subjectivity=0.825)
# 159. Sentiment(polarity=0.11666666666666665, subjectivity=0.8833333333333333)
# 160. Sentiment(polarity=0.0, subjectivity=1.0)
# 161. Sentiment(polarity=0.16666666666666666, subjectivity=0.6)
# 162. Sentiment(polarity=0.0, subjectivity=0.0)
# 163. Sentiment(polarity=-0.025000000000000022, subjectivity=0.875)
# 164. Sentiment(polarity=0.06818181818181818, subjectivity=0.25)
# 165. Sentiment(polarity=-0.5, subjectivity=1.0)
# 166. Sentiment(polarity=0.5, subjectivity=0.5)
# 167. Sentiment(polarity=0.0, subjectivity=0.0)
# 168. Sentiment(polarity=0.0, subjectivity=0.0)
# 169. Sentiment(polarity=-0.5, subjectivity=1.0)
# 170. Sentiment(polarity=0.0, subjectivity=0.0)
# 171. Sentiment(polarity=0.08333333333333333, subjectivity=0.16666666666666666)
# 172. Sentiment(polarity=-0.05555555555555555, subjectivity=0.05555555555555555)
# 173. Sentiment(polarity=0.0, subjectivity=0.0)
# 174. Sentiment(polarity=0.0, subjectivity=0.0)
# 175. Sentiment(polarity=0.39285714285714285, subjectivity=0.5178571428571428)
# 176. Sentiment(polarity=0.0, subjectivity=0.0)
# 177. Sentiment(polarity=0.3, subjectivity=0.8666666666666667)
# 178. Sentiment(polarity=0.25, subjectivity=0.3)
# 179. Sentiment(polarity=-0.14583333333333334, subjectivity=0.3333333333333333)
# 180. Sentiment(polarity=0.1875, subjectivity=0.23333333333333334)
# 181. Sentiment(polarity=0.0, subjectivity=0.0)
# 182. Sentiment(polarity=0.1, subjectivity=0.2)
# 183. Sentiment(polarity=0.3125, subjectivity=0.3333333333333333)
# 184. Sentiment(polarity=0.0, subjectivity=0.0)
# 185. Sentiment(polarity=0.4375, subjectivity=0.55)
# 186. Sentiment(polarity=0.0, subjectivity=0.0)
# 187. Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# 188. Sentiment(polarity=0.125, subjectivity=0.6666666666666666)
# 189. Sentiment(polarity=0.13333333333333333, subjectivity=0.19999999999999998)
# 190. Sentiment(polarity=0.0, subjectivity=0.0)
# 191. Sentiment(polarity=0.7, subjectivity=0.8)
# 192. Sentiment(polarity=0.0, subjectivity=0.0)
# 193. Sentiment(polarity=0.0, subjectivity=0.0)
# 194. Sentiment(polarity=0.5, subjectivity=0.6)
# 195. Sentiment(polarity=0.7000000000000001, subjectivity=0.825)
# 196. Sentiment(polarity=0.5, subjectivity=0.6)
# 197. Sentiment(polarity=0.04464285714285714, subjectivity=0.5089285714285714)
# 198. Sentiment(polarity=-0.45099718035275094, subjectivity=0.8211859527921701)
# 199. Sentiment(polarity=0.4375, subjectivity=0.65)
# 200. Sentiment(polarity=0.0, subjectivity=0.0)

# %%
"""CIS 2532 NET 01
Dr. Shamsuddin
Kostas Spyropoulos
HW 7 
Program performs various uses of NLP
Exercise 12.3"""
import requests
import nltk
from nltk.corpus import stopwords
import imageio
from wordcloud import WordCloud
from textblob import TextBlob
import matplotlib.pyplot as plt
from textblob.sentiments import NaiveBayesAnalyzer
from bs4 import BeautifulSoup
from unidecode import unidecode
from textblob import Word
from spellchecker import SpellChecker

# Exercise 12.3

print('Exercise 12.3')
print()

# the get function gets the URL argument and sends the URL's webpage as a Response object
response = requests.get('https://www.cnn.com/2022/03/25/entertainment/taylor-hawkins-foo-fighters-obit/index.html')

# reponse.content possesses web page's composition
response.content 

# BeautifulSoup object is made to analyze text of response.content
soup = BeautifulSoup(response.content,'html5lib')

# text of website is returned without web browser structural info
text = soup.get_text(strip=True)

# blob is equal to textblob of 'https://www.cnn.com/2022/03/25/entertainment/taylor-hawkins-foo-fighters-obit/index.html'
blob = TextBlob(text)

print()
print('Overall sentiment of https://www.cnn.com/2022/03/25/entertainment/taylor-hawkins-foo-fighters-obit/index.html')

# print the sentiment of overall blob
print(blob.sentiment)
print()

print('Sentiment of each sentence of https://www.cnn.com/2022/03/25/entertainment/taylor-hawkins-foo-fighters-obit/index.html')

counter = 0
# print the sentiment of every sentence in blob
for sentence in blob.sentences:
    counter = counter + 1
    # counter represents cardinal number of sentence sentiment
    print(str(counter) + str(". ")+ str(sentence.sentiment))
# Out:
# Exercise 12.3
#
#
# Overall sentiment of https://www.cnn.com/2022/03/25/entertainment/taylor-hawkins-foo-fighters-obit/index.html
# Sentiment(polarity=-0.3805922433264658, subjectivity=0.7822017843536253)
#
# Sentiment of each sentence of https://www.cnn.com/2022/03/25/entertainment/taylor-hawkins-foo-fighters-obit/index.html
# 1. Sentiment(polarity=-0.375, subjectivity=0.55)
# 2. Sentiment(polarity=-0.17158723153868777, subjectivity=0.45769659143445574)
# 3. Sentiment(polarity=-0.75, subjectivity=1.0)
# 4. Sentiment(polarity=0.5, subjectivity=0.5)
# 5. Sentiment(polarity=0.0, subjectivity=0.0)
# 6. Sentiment(polarity=0.0, subjectivity=0.0)
# 7. Sentiment(polarity=-0.28534080298786196, subjectivity=0.7247432306255835)
# 8. Sentiment(polarity=0.0, subjectivity=0.0)
# 9. Sentiment(polarity=0.0, subjectivity=0.0)
# 10. Sentiment(polarity=-0.25, subjectivity=0.6)
# 11. Sentiment(polarity=-0.125, subjectivity=0.75)
# 12. Sentiment(polarity=0.0, subjectivity=0.0)
# 13. Sentiment(polarity=0.0, subjectivity=0.0)
# 14. Sentiment(polarity=0.0, subjectivity=0.3333333333333333)
# 15. Sentiment(polarity=0.0, subjectivity=0.3)
# 16. Sentiment(polarity=0.0, subjectivity=0.0)
# 17. Sentiment(polarity=-0.4, subjectivity=0.7)
# 18. Sentiment(polarity=0.0, subjectivity=0.0)
# 19. Sentiment(polarity=0.5, subjectivity=0.15)
# 20. Sentiment(polarity=0.0, subjectivity=0.5)
# 21. Sentiment(polarity=0.21428571428571427, subjectivity=0.6428571428571429)
# 22. Sentiment(polarity=0.175, subjectivity=0.49000000000000005)
# 23. Sentiment(polarity=0.0, subjectivity=0.0)
# 24. Sentiment(polarity=0.0, subjectivity=0.0)
# 25. Sentiment(polarity=0.0, subjectivity=0.0)
# 26. Sentiment(polarity=0.0, subjectivity=0.0)
# 27. Sentiment(polarity=0.7, subjectivity=0.9)
# 28. Sentiment(polarity=0.06666666666666667, subjectivity=0.39999999999999997)
# 29. Sentiment(polarity=0.0, subjectivity=0.0)
# 30. Sentiment(polarity=0.0, subjectivity=0.0)
# 31. Sentiment(polarity=0.0, subjectivity=0.0)
# 32. Sentiment(polarity=0.5, subjectivity=0.5)
# 33. Sentiment(polarity=0.0, subjectivity=0.0)
# 34. Sentiment(polarity=0.35, subjectivity=0.65)
# 35. Sentiment(polarity=1.0, subjectivity=0.3)
# 36. Sentiment(polarity=0.0, subjectivity=0.0)
# 37. Sentiment(polarity=0.35, subjectivity=0.65)
# 38. Sentiment(polarity=0.3333333333333333, subjectivity=0.6666666666666666)
# 39. Sentiment(polarity=0.35, subjectivity=0.65)
# 40. Sentiment(polarity=0.25909090909090904, subjectivity=0.4636363636363636)
# 41. Sentiment(polarity=0.43333333333333335, subjectivity=0.8333333333333334)
# 42. Sentiment(polarity=0.4, subjectivity=0.425)
# 43. Sentiment(polarity=0.0, subjectivity=0.0)
# 44. Sentiment(polarity=0.8, subjectivity=0.75)
# 45. Sentiment(polarity=-0.2380952380952381, subjectivity=0.48571428571428577)
# 46. Sentiment(polarity=0.0, subjectivity=0.0)
# 47. Sentiment(polarity=0.0, subjectivity=0.0)
# 48. Sentiment(polarity=0.0, subjectivity=0.0)
# 49. Sentiment(polarity=0.0, subjectivity=0.0)
# 50. Sentiment(polarity=0.35, subjectivity=0.65)
# 51. Sentiment(polarity=0.4330357142857143, subjectivity=0.7053571428571428)
# 52. Sentiment(polarity=0.0, subjectivity=0.0)
# 53. Sentiment(polarity=0.0, subjectivity=0.0)
# 54. Sentiment(polarity=0.0, subjectivity=0.0)
# 55. Sentiment(polarity=0.0, subjectivity=0.0)
# 56. Sentiment(polarity=1.0, subjectivity=0.3)
# 57. Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# 58. Sentiment(polarity=0.0, subjectivity=0.0)
# 59. Sentiment(polarity=0.0, subjectivity=0.0)
# 60. Sentiment(polarity=0.43333333333333335, subjectivity=0.6)
# 61. Sentiment(polarity=0.0, subjectivity=0.0)
# 62. Sentiment(polarity=0.0, subjectivity=0.0)
# 63. Sentiment(polarity=0.0, subjectivity=0.0)
# 64. Sentiment(polarity=0.0, subjectivity=0.0)
# 65. Sentiment(polarity=0.0, subjectivity=0.0)
# 66. Sentiment(polarity=0.0, subjectivity=0.0)
# 67. Sentiment(polarity=0.0, subjectivity=0.0)
# 68. Sentiment(polarity=0.0, subjectivity=0.0)
# 69. Sentiment(polarity=0.0, subjectivity=0.0)
# 70. Sentiment(polarity=-0.37940539852304556, subjectivity=0.867436974789916)
# 71. Sentiment(polarity=-0.6031088082901558, subjectivity=0.9138601036269428)
# 72. Sentiment(polarity=0.0, subjectivity=0.0)
# 73. Sentiment(polarity=-0.491304347826087, subjectivity=0.7956521739130435)
# 74. Sentiment(polarity=0.040000000000000015, subjectivity=0.72)
# 75. Sentiment(polarity=0.0, subjectivity=0.0)
# 76. Sentiment(polarity=0.0, subjectivity=1.0)
# 77. Sentiment(polarity=-0.5, subjectivity=0.6666666666666666)
# 78. Sentiment(polarity=0.0, subjectivity=0.0)
# 79. Sentiment(polarity=-0.25, subjectivity=0.3333333333333333)
# 80. Sentiment(polarity=0.0, subjectivity=0.0)
# 81. Sentiment(polarity=-0.2681818181818182, subjectivity=0.656060606060606)
# 82. Sentiment(polarity=-0.053125000000000006, subjectivity=0.4125)
# 83. Sentiment(polarity=-0.03697916666666667, subjectivity=0.20416666666666666)
# 84. Sentiment(polarity=-0.008333333333333331, subjectivity=0.125)
# 85. Sentiment(polarity=0.0, subjectivity=0.1)
# 86. Sentiment(polarity=-0.75, subjectivity=1.0)
# 87. Sentiment(polarity=0.0, subjectivity=0.0)
# 88. Sentiment(polarity=-0.125, subjectivity=0.75)
# 89. Sentiment(polarity=-0.32142857142857145, subjectivity=0.42857142857142855)
# 90. Sentiment(polarity=0.040000000000000015, subjectivity=0.72)
# 91. Sentiment(polarity=0.0, subjectivity=0.0)
# 92. Sentiment(polarity=0.0, subjectivity=1.0)
# 93. Sentiment(polarity=-0.5, subjectivity=0.6666666666666666)
# 94. Sentiment(polarity=0.0, subjectivity=0.0)
# 95. Sentiment(polarity=-0.25, subjectivity=0.3333333333333333)
# 96. Sentiment(polarity=0.0, subjectivity=0.0)
# 97. Sentiment(polarity=-0.2681818181818182, subjectivity=0.656060606060606)
# 98. Sentiment(polarity=-0.053125000000000006, subjectivity=0.4125)
# 99. Sentiment(polarity=-0.03697916666666667, subjectivity=0.20416666666666666)
# 100. Sentiment(polarity=-0.008333333333333331, subjectivity=0.125)
# 101. Sentiment(polarity=0.0, subjectivity=0.1)
# 102. Sentiment(polarity=-0.75, subjectivity=1.0)
# 103. Sentiment(polarity=0.0, subjectivity=0.0)
# 104. Sentiment(polarity=-0.125, subjectivity=0.75)
# 105. Sentiment(polarity=-0.1392857142857143, subjectivity=0.688095238095238)
# 106. Sentiment(polarity=0.0, subjectivity=0.0)
# 107. Sentiment(polarity=0.25, subjectivity=0.45)
# 108. Sentiment(polarity=-0.11428571428571428, subjectivity=0.6630952380952381)
# 109. Sentiment(polarity=0.20000000000000004, subjectivity=0.43333333333333335)
# 110. Sentiment(polarity=-0.23714285714285716, subjectivity=0.6957142857142856)
# 111. Sentiment(polarity=-0.19090909090909092, subjectivity=0.8590909090909092)
# 112. Sentiment(polarity=-0.75, subjectivity=1.0)
# 113. Sentiment(polarity=0.5, subjectivity=0.5)
# 114. Sentiment(polarity=0.0, subjectivity=0.0)
# 115. Sentiment(polarity=0.0, subjectivity=0.0)
# 116. Sentiment(polarity=-0.5203125, subjectivity=0.903125)
# 117. Sentiment(polarity=0.0, subjectivity=0.0)
# 118. Sentiment(polarity=-0.375, subjectivity=0.7)
# 119. Sentiment(polarity=-0.75, subjectivity=1.0)
# 120. Sentiment(polarity=-0.75, subjectivity=1.0)
# 121. Sentiment(polarity=-0.48131313131313136, subjectivity=0.8222222222222224)
# 122. Sentiment(polarity=0.0, subjectivity=0.0)
# 123. Sentiment(polarity=-0.34999999999999987, subjectivity=0.8121212121212118)
# 124. Sentiment(polarity=-0.3468442501105831, subjectivity=0.8595397623035782)
# 125. Sentiment(polarity=0.0, subjectivity=0.0)
# 126. Sentiment(polarity=-0.375, subjectivity=0.7)
# 127. Sentiment(polarity=-0.75, subjectivity=1.0)
# 128. Sentiment(polarity=-0.75, subjectivity=1.0)
# 129. Sentiment(polarity=-0.48131313131313136, subjectivity=0.8222222222222224)
# 130. Sentiment(polarity=0.0, subjectivity=0.0)
# 131. Sentiment(polarity=-0.33409090909090894, subjectivity=0.7878787878787876)
# 132. Sentiment(polarity=0.0, subjectivity=0.0)
# 133. Sentiment(polarity=0.0, subjectivity=0.0)
# 134. Sentiment(polarity=0.0, subjectivity=0.0)
# 135. Sentiment(polarity=0.0, subjectivity=0.0)
# 136. Sentiment(polarity=-0.2520833333333334, subjectivity=0.425)
# 137. Sentiment(polarity=-0.44270007118161553, subjectivity=0.8017897091722591)
# 138. Sentiment(polarity=0.040000000000000015, subjectivity=0.72)
# 139. Sentiment(polarity=0.0, subjectivity=0.0)
# 140. Sentiment(polarity=0.0, subjectivity=1.0)
# 141. Sentiment(polarity=-0.5, subjectivity=0.6666666666666666)
# 142. Sentiment(polarity=0.0, subjectivity=0.0)
# 143. Sentiment(polarity=-0.25, subjectivity=0.3333333333333333)
# 144. Sentiment(polarity=0.0, subjectivity=0.0)
# 145. Sentiment(polarity=-0.2681818181818182, subjectivity=0.656060606060606)
# 146. Sentiment(polarity=-0.053125000000000006, subjectivity=0.4125)
# 147. Sentiment(polarity=-0.03697916666666667, subjectivity=0.20416666666666666)
# 148. Sentiment(polarity=-0.008333333333333331, subjectivity=0.125)
# 149. Sentiment(polarity=0.0, subjectivity=0.1)
# 150. Sentiment(polarity=-0.75, subjectivity=1.0)
# 151. Sentiment(polarity=0.0, subjectivity=0.0)
# 152. Sentiment(polarity=-0.125, subjectivity=0.75)
# 153. Sentiment(polarity=-0.453125, subjectivity=0.5916666666666667)
# 154. Sentiment(polarity=-0.20000000000000004, subjectivity=0.5625)
# 155. Sentiment(polarity=-0.46813186813186813, subjectivity=0.782967032967033)
# 156. Sentiment(polarity=0.35, subjectivity=0.65)
# 157. Sentiment(polarity=0.009987148268398268, subjectivity=0.5296536796536797)
# 158. Sentiment(polarity=-0.2, subjectivity=0.825)
# 159. Sentiment(polarity=0.11666666666666665, subjectivity=0.8833333333333333)
# 160. Sentiment(polarity=0.0, subjectivity=1.0)
# 161. Sentiment(polarity=0.16666666666666666, subjectivity=0.6)
# 162. Sentiment(polarity=0.0, subjectivity=0.0)
# 163. Sentiment(polarity=-0.025000000000000022, subjectivity=0.875)
# 164. Sentiment(polarity=0.06818181818181818, subjectivity=0.25)
# 165. Sentiment(polarity=-0.5, subjectivity=1.0)
# 166. Sentiment(polarity=0.5, subjectivity=0.5)
# 167. Sentiment(polarity=0.0, subjectivity=0.0)
# 168. Sentiment(polarity=0.0, subjectivity=0.0)
# 169. Sentiment(polarity=-0.5, subjectivity=1.0)
# 170. Sentiment(polarity=0.0, subjectivity=0.0)
# 171. Sentiment(polarity=0.08333333333333333, subjectivity=0.16666666666666666)
# 172. Sentiment(polarity=-0.05555555555555555, subjectivity=0.05555555555555555)
# 173. Sentiment(polarity=0.0, subjectivity=0.0)
# 174. Sentiment(polarity=0.0, subjectivity=0.0)
# 175. Sentiment(polarity=0.39285714285714285, subjectivity=0.5178571428571428)
# 176. Sentiment(polarity=0.0, subjectivity=0.0)
# 177. Sentiment(polarity=0.3, subjectivity=0.8666666666666667)
# 178. Sentiment(polarity=0.25, subjectivity=0.3)
# 179. Sentiment(polarity=-0.14583333333333334, subjectivity=0.3333333333333333)
# 180. Sentiment(polarity=0.1875, subjectivity=0.23333333333333334)
# 181. Sentiment(polarity=0.0, subjectivity=0.0)
# 182. Sentiment(polarity=0.1, subjectivity=0.2)
# 183. Sentiment(polarity=0.3125, subjectivity=0.3333333333333333)
# 184. Sentiment(polarity=0.0, subjectivity=0.0)
# 185. Sentiment(polarity=0.4375, subjectivity=0.55)
# 186. Sentiment(polarity=0.0, subjectivity=0.0)
# 187. Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# 188. Sentiment(polarity=0.125, subjectivity=0.6666666666666666)
# 189. Sentiment(polarity=0.13333333333333333, subjectivity=0.19999999999999998)
# 190. Sentiment(polarity=0.0, subjectivity=0.0)
# 191. Sentiment(polarity=0.7, subjectivity=0.8)
# 192. Sentiment(polarity=0.0, subjectivity=0.0)
# 193. Sentiment(polarity=0.0, subjectivity=0.0)
# 194. Sentiment(polarity=0.5, subjectivity=0.6)
# 195. Sentiment(polarity=0.7000000000000001, subjectivity=0.825)
# 196. Sentiment(polarity=0.5, subjectivity=0.6)
# 197. Sentiment(polarity=0.04464285714285714, subjectivity=0.5089285714285714)
# 198. Sentiment(polarity=-0.45099718035275094, subjectivity=0.8211859527921701)
# 199. Sentiment(polarity=0.4375, subjectivity=0.65)
# 200. Sentiment(polarity=0.0, subjectivity=0.0)
